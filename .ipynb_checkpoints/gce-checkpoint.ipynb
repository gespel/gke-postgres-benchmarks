# %% [markdown]
# # Google Kubernetes Engine PostgreSQL Laufzeitanalyse
# Im Rahmen der folgenden Untersuchung werden verschiedene Maschinentypen der Google Kubernetes Engine (kurz GKE) hinsichtlich der Laufzeit und der Transaktionsdauer einer PostgreSQL-Datenbank analysiert. Hierbei wird jeweils ein Kubernetes-Cluster erstellt, das aus einem Knoten des jeweiligen Maschinentyps besteht, auf dem ein CloudNativePG-Cluster gestartet wird. Letzteres besteht, da es sich hierbei um einen reinen Leistungsvergleich handelt, lediglich aus einem Clusterknoten. Damit ist gewährleistet, dass bei dem gewählten Benchmark keine Clusterauslagerungen stattfinden und wir somit die reine Performance der Maschine betrachten können.
# ## Benchmark und Details
# Google verwendet für die Knoten bzw. die Kubernetes-Implementierung den klassischen Containerd-Service. Dieser bildet die Schnittstelle zwischen dem Host-Betriebssystem und Kubernetes. Benötigt eine Applikation Hardware-Ressourcen, werden diese wie bei einem Bare-Metal-Server sofort bereitgestellt. Da wir in der folgenden Versuchsreihe einen einzelnen Clusterknoten verwenden, muss Kubernetes keine Synchronisation zwischen Knoten vornehmen. Somit können wir die Performance von Kubernetes, dem Containerd-Service, dem Host-Betriebssystem und der Hardware als gute Messumgebung nutzen, und es ist kein Overhead zu erwarten.
#
# Als Benchmark-Suite wurde der von PostgreSQL selbst entwickelte pgbench verwendet. Dieser wird auf einer weiteren GCloud-VM ausgeführt und somit, im Gegensatz zur vorherigen Messreihe, nicht im Cluster selbst. Damit repräsentiert die erzielte Leistung lediglich die Clusterleistung selbst, ohne dass ein Overhead durch den im Cluster ausgeführten Benchmark entsteht.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
from matplotlib.ticker import AutoMinorLocator

colors = ["blue", "green", "red", "cyan", "magenta", "yellow"]

def visualize(data, title):
    df = pd.DataFrame(data)

    df_sorted = df.sort_values("CPU CORES ALLOCATED")

    plt.figure(figsize=(10, 6))
    plt.plot(
        df_sorted["CPU CORES ALLOCATED"], 
        df_sorted["TPS"], 
        marker="o", 
        linestyle="-", 
        label="Transactions per Second",
        linewidth=4,
        markersize=15,
    )
    plt.title(title, fontsize=16)
    plt.xlabel("CPU Cores Allocated", fontsize=14)
    plt.ylabel("Transactions per Second", fontsize=14)
    plt.xticks(df_sorted["CPU CORES ALLOCATED"], fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(axis="both", linestyle="-", alpha=0.7)
    plt.legend(fontsize=12)
    plt.tight_layout()
    plt.show()

def n_visualize(data, title):
    plt.figure(figsize=(10, 6))
    for d in data:
        df = pd.DataFrame(d[0])

        df_sorted = df.sort_values("CPU CORES ALLOCATED")

        
        plt.plot(
            df_sorted["CPU CORES ALLOCATED"], 
            df_sorted["TPS"],
            marker="o", 
            linestyle="-", 
            label=d[1],
            linewidth=3,
            markersize=10,
        )
    plt.title(title, fontsize=16)
    plt.xlabel("CPU Cores Allocated", fontsize=14)
    plt.ylabel("Transactions per Second", fontsize=14)
    plt.xticks(df_sorted["CPU CORES ALLOCATED"], fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(axis="both", linestyle="-", alpha=0.7)
    plt.legend(fontsize=12)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## E2 Standard
# Zunächst untersuchen wir einen der klassischen Maschinentypen in einer Google-Cloud-Umgebung. Die E2-Maschinen werden von Google selbst als kostengünstige Alltags-VMs beworben. Sie können auf unterschiedlichen Hardware-Architekturen laufen, wodurch Google weitere Kosten sparen kann, indem beispielsweise Knoten in ihrer Infrastruktur, die derzeit nicht genutzt werden, vermietet werden. Dabei kommen alle gängigen x86_64-Prozessorhersteller zum Einsatz. In unseren Tests wurden uns vor allem AMD-Epyc-Prozessoren zur Verfügung gestellt.

# %%
data_e2 = {
    "MACHINE TYPE": [
        "e2-standard-32", 
        "e2-standard-16", 
        "e2-standard-8", 
        "e2-standard-4",
        "e2-standard-2"
    ],
    "CPU TYPE": ["e2", "e2", "e2", "e2", "e2"],
    "CPU CORES ALLOCATED": [32, 16, 8, 4, 2],
    "TPS": [205116.731071, 110503.320857, 45397.606615, 22954.238914, 7222.776990]
}
visualize(data_e2, "TPS vs. CPU Cores Allocated (E2 Standard Machine Type)")

# %% [markdown]
# ### Auswertung
# Die obere Messreihe zeigt deutlich eine lineare Skalierung der Transaktionen pro Sekunde. Dies spricht für einen ausgezeichneten Parallelisierungsgrad der getesteten PostgreSQL-Implementierung. Dabei konnte auf einer 32-Kern-Maschine ein TPS-Spitzenwert von knapp 210.000 erreicht werden. Dieser Wert liegt auf Augenhöhe mit gängigen lokal gehosteten Datenbanken und kann problemlos durch das Hinzufügen weiterer Rechenkapazitäten in Form von Kernen nach oben skaliert werden.
#
# Spannend ist hierbei auch, dass die Größe des Arbeitsspeichers keinen Einfluss auf die Transaktionsrate hat. Dies lässt sich vor allem durch die Architektur von PostgreSQL erklären, da diese eher auf CPU-Caching und direkten Festplattenzugriff als auf "In-Memory"-Verarbeitung setzt.
#
# Eine Extrapolation der Kurve zeigt ein potenzielles lokales Maximum der TPS, das vermutlich bei etwa 64 Kernen mit 350.000 TPS erreicht wird.

# %% [markdown]
# ## C3D Standard
# Bei der C-Familie der Google-Cloud-Maschinen handelt es sich um Maschinentypen, die vor allem für rechenintensive Prozesse verwendet werden. Dabei können Prozessorarchitekturen sowie Hersteller explizit ausgewählt werden.
#
# Die C3D-Maschinenfamilie nutzt die modernsten AMD-Epyc-Genoa-Prozessoren, die sich insbesondere durch ihre extrem großen Cache-Größen auszeichnen und bis zu 96 Kerne auf einem einzelnen Prozessor bieten. Hierbei werden vier NUMA-Domains verwendet.
#
# Im Vergleich zur E2-Messreihe im vorherigen Abschnitt konnten für die C3D-Familie nur Maschinen mit 4 bis 16 Kernen getestet werden. Grund dafür ist, dass Google keine Zwei-Kern-Maschinen in dieser Familie anbietet und eine interne Richtlinie von Google die Nutzung von VMs mit mehr als 24 Kernen aus der C3D-Familie ohne spezielle Genehmigung verbietet. Möchte man dennoch mehr Kerne verwenden, muss hierfür eine Genehmigung bei Google beantragt werden.

# %%
data_c3d = {
    "MACHINE TYPE": [
        "c3d-standard-16", 
        "c3d-standard-8", 
        "c3d-standard-4"
    ],
    "CPU TYPE": ["c3d", "c3d", "c3d"],
    "CPU CORES ALLOCATED": [16, 8, 4],
    "TPS": [149609.066347, 75511.570651, 31017.311826]
}
visualize(data_c3d, "TPS vs. CPU Cores Allocated (C3D Standard Machine Type)")

# %% [markdown]
# ### Auswertung
# Die durchgeführte Messreihe verdeutlicht hervorragend, wie stark Anwendungen von modernen Prozessorarchitekturen profitieren können. Die Prozessoren der E2-Familie besitzen zwar die gleiche Taktfrequenz wie die der C3D-Familie, jedoch sind letztere durchweg deutlich leistungsstärker. So erreichen wir mit 16 C3D-Kernen nahezu die gleiche Anzahl an Transaktionen pro Sekunde, die eine E2-Maschine mit der doppelten Anzahl an Prozessorkernen erzielen konnte. Gerade aber auch bei geringerer Prozessoranzahl sehen wir fast das doppelter der TPS Werte eine E2-Maschine

# %% [markdown]
# ## C2 Standard

# %% [markdown]
# C2-Maschinen sind denen der C3D-Familie sehr ähnlich. Allerdings wird bei Ihnen ein Intel Prozessor der vorrigen Generation verwendet. Dabei kommt vorallem die Cascade Lake (2. Generation Intel scaleable) zum Einsatz.
# Ansonsten gelten die gleichen Richtlinien wie schon bei den C3D Messungen, da es sich hierbei auch hierbei ebenfalls um Maschinen von Google handelt, die als  Performance Maschinen beworben werden. Die kleinste verfügbare Maschine besitzt 4 Kerne.

# %%
data_c2 = {
    "MACHINE TYPE": [
        "c2-standard-16", 
        "c2-standard-8", 
        "c2-standard-4"
    ],
    "CPU TYPE": ["c2", "c2", "c2"],
    "CPU CORES ALLOCATED": [16, 8, 4],
    "TPS": [141465.288866, 71311.623489, 27293.374996]
}
visualize(data_c2, "TPS vs. CPU Cores Allocated (C2 Standard Machine Type)")

# %% [markdown]
# ### Auswertung
# Wie bei einer Vorgängergeneration von Prozessoren der Moderene zu erwarten war, lässt sich nur eine kleine Performance Einbuße zur Nachfolgegeneration beobachten. Schneller als die Allround E2-Maschine, sind diese Prozessoren jedoch allemal. Zusätzlich, sei erwähnt, dass die C2-Maschinen günstiger als diese der C3D Generation sind.

# %% [markdown]
# ## E2 High CPU

# %%
data_e2_highcpu = {
    "MACHINE TYPE": [
        "e2-highcpu-32", 
        "e2-highcpu-16", 
        "e2-highcpu-8", 
        "e2-highcpu-4",
        "e2-highcpu-2"
    ],
    "CPU TYPE": ["e2", "e2", "e2", "e2", "e2"],
    "CPU CORES ALLOCATED": [32, 16, 8, 4, 2],
    "TPS": [197131.013784, 108934.423893, 51908.272391, 24243.429329, 12914.810610]
}
visualize(data_e2_highcpu, "TPS vs. CPU Cores Allocated (E2 High CPU Machine Type)")

# %% [markdown]
# ## C3D High CPU

# %%
data_c3d_highcpu = {
    "MACHINE TYPE": [
        "c3d-highcpu-16", 
        "c3d-highcpu-8", 
        "c3d-highcpu-4"
    ],
    "CPU TYPE": ["c3d", "c3d", "c3d"],
    "CPU CORES ALLOCATED": [16, 8, 4],
    "TPS": [152373.910723, 79634.847100, 41597.235143]
}
visualize(data_c3d_highcpu, "TPS vs. CPU Cores Allocated (C3D High CPU Machine Type)")

# %% [markdown]
# ## C2D High CPU

# %%
data_c2d_highcpu = {
    "MACHINE TYPE": [
        "c3d-highcpu-16", 
        "c3d-highcpu-8", 
        "c3d-highcpu-4",
        "c2d-highcpu-2"
    ],
    "CPU TYPE": ["c2d", "c2d", "c2d", "c2d"],
    "CPU CORES ALLOCATED": [16, 8, 4, 2],
    "TPS": [125388.719200, 65645.295948, 35267.328374, 19401.256968]
}
visualize(data_c2d_highcpu, "TPS vs. CPU Cores Allocated (C2D High CPU Machine Type)")

# %% [markdown]
# # Allgemeine Auswertung

# %%
n_visualize([(data_e2, "e2-standard"), (data_c3d, "c3d-standard"), (data_c2, "c2-standard"), (data_e2_highcpu, "e2-highcpu"), (data_c3d_highcpu, "c3d-highcpu"), (data_c2d_highcpu, "c2d-highcpu")], "Bringing it all together")

# %% [markdown]
# ## Performance/Dollar

# %%
price_hourly = {
    "c3d-standard-16": 0.896112,
    "c3d-standard-8": 0.448056,
    "c3d-standard-4": 0.224028,
    "e2-standard-32": 1.402415,
    "e2-standard-16": 0.701207,
    "e2-standard-8": 0.350604,
    "e2-standard-4": 0.175302,
    "e2-standard-2": 0.087651,
    "e2-highcpu-32": 1.035313,
    "e2-highcpu-16": 0.517657,
    "e2-highcpu-8": 0.258828,
    "e2-highcpu-4": 0.129414,
    "e2-highcpu-2": 0.064707,
    "c2-standard-16": 0.967088,
    "c2-standard-8": 0.483544,
    "c2-standard-4": 0.241772,
    "c3d-highcpu-4": 0.17691,
    "c3d-highcpu-8": 0.353821,
    "c3d-highcpu-16": 0.707641,
    "c2d-highcpu-2": 0.087,
    "c2d-highcpu-4": 0.1739,
    "c2d-highcpu-8": 0.3478,
    "c2d-highcpu-16": 0.6957
}
def print_tps_per_dollar(data):
    for i in range(0, len(data["MACHINE TYPE"])):
        print(data["MACHINE TYPE"][i] + ": " + str(float(data["TPS"][i])/price_hourly[data["MACHINE TYPE"][i]]) + " TPS/$")
    print()

print_tps_per_dollar(data_e2)
print_tps_per_dollar(data_c3d)
print_tps_per_dollar(data_c2)
print_tps_per_dollar(data_e2_highcpu)
# Out:
# e2-standard-32: 146259.65286380993 TPS/$
# e2-standard-16: 157590.15648303568 TPS/$
# e2-standard-8: 129483.99509132809 TPS/$
# e2-standard-4: 130941.11256003924 TPS/$
# e2-standard-2: 82403.81729814834 TPS/$
#
# c3d-standard-16: 166953.53521323227 TPS/$
# c3d-standard-8: 168531.54661694073 TPS/$
# c3d-standard-4: 138452.83547592265 TPS/$
#
# c2-standard-16: 146279.6445266615 TPS/$
# c2-standard-8: 147477.0103423887 TPS/$
# c2-standard-4: 112888.89944244991 TPS/$
#
# e2-highcpu-32: 190407.1655470375 TPS/$
# e2-highcpu-16: 210437.459346633 TPS/$
# e2-highcpu-8: 200551.22471680035 TPS/$
# e2-highcpu-4: 187332.3545288763 TPS/$
# e2-highcpu-2: 199589.08016134266 TPS/$

# %%
price_data_e2 = {
    "CPU CORES ALLOCATED": data_e2["CPU CORES ALLOCATED"],
    "TPS PER DOLLAR": [data_e2["TPS"][i]/price_hourly[data_e2["MACHINE TYPE"][i]] for i in range(0, len(data_e2["CPU CORES ALLOCATED"]))]
}
price_data_c3d = {
    "CPU CORES ALLOCATED": data_c3d["CPU CORES ALLOCATED"],
    "TPS PER DOLLAR": [data_c3d["TPS"][i]/price_hourly[data_c3d["MACHINE TYPE"][i]] for i in range(0, len(data_c3d["CPU CORES ALLOCATED"]))]
}
price_data_c2 = {
    "CPU CORES ALLOCATED": data_c2["CPU CORES ALLOCATED"],
    "TPS PER DOLLAR": [data_c2["TPS"][i]/price_hourly[data_c2["MACHINE TYPE"][i]] for i in range(0, len(data_c2["CPU CORES ALLOCATED"]))]
}
price_data_e2_highcpu = {
    "CPU CORES ALLOCATED": data_e2_highcpu["CPU CORES ALLOCATED"],
    "TPS PER DOLLAR": [data_e2_highcpu["TPS"][i]/price_hourly[data_e2_highcpu["MACHINE TYPE"][i]] for i in range(0, len(data_e2_highcpu["CPU CORES ALLOCATED"]))]
}
price_data_c3d_highcpu = {
    "CPU CORES ALLOCATED": data_c3d_highcpu["CPU CORES ALLOCATED"],
    "TPS PER DOLLAR": [data_c3d_highcpu["TPS"][i]/price_hourly[data_c3d_highcpu["MACHINE TYPE"][i]] for i in range(0, len(data_c3d_highcpu["CPU CORES ALLOCATED"]))]
}
price_data_c2d_highcpu = {
    "CPU CORES ALLOCATED": data_c2d_highcpu["CPU CORES ALLOCATED"],
    "TPS PER DOLLAR": [data_c2d_highcpu["TPS"][i]/price_hourly[data_c2d_highcpu["MACHINE TYPE"][i]] for i in range(0, len(data_c2d_highcpu["CPU CORES ALLOCATED"]))]
}

e2_price_df = pd.DataFrame(price_data_e2)
c3d_price_df = pd.DataFrame(price_data_c3d)
c2_price_df = pd.DataFrame(price_data_c2)
e2_high_cpu_price_df = pd.DataFrame(price_data_e2_highcpu)
c3d_high_cpu_price_df = pd.DataFrame(price_data_c3d_highcpu)
c2d_high_cpu_price_df = pd.DataFrame(price_data_c2d_highcpu)

e2_price_df_sorted = e2_price_df.sort_values("CPU CORES ALLOCATED")
c3d_price_df_sorted = c3d_price_df.sort_values("CPU CORES ALLOCATED")
c2_price_df_sorted = c2_price_df.sort_values("CPU CORES ALLOCATED")
e2_high_cpu_price_df_sorted = e2_high_cpu_price_df.sort_values("CPU CORES ALLOCATED")
c3d_high_cpu_price_df_sorted = c3d_high_cpu_price_df.sort_values("CPU CORES ALLOCATED")
c2d_high_cpu_price_df_sorted = c2d_high_cpu_price_df.sort_values("CPU CORES ALLOCATED")

plt.figure(figsize=(10, 6))
plt.plot(
    e2_price_df_sorted["CPU CORES ALLOCATED"], 
    e2_price_df_sorted["TPS PER DOLLAR"], 
    marker="o", 
    linestyle="-", 
    color=f"#{random.randint(0, 0xFFFFFF):06x}", 
    label="e2-standard",
    linewidth=4,
    markersize=15,
)
plt.plot(
    c3d_price_df_sorted["CPU CORES ALLOCATED"], 
    c3d_price_df_sorted["TPS PER DOLLAR"], 
    marker="o", 
    linestyle="-", 
    label="c3d-standard",
    linewidth=4,
    markersize=15,
)
plt.plot(
    c2_price_df_sorted["CPU CORES ALLOCATED"], 
    c2_price_df_sorted["TPS PER DOLLAR"], 
    marker="o", 
    linestyle="-", 
    label="c2-standard",
    linewidth=4,
    markersize=15,
)
plt.plot(
    e2_high_cpu_price_df_sorted["CPU CORES ALLOCATED"], 
    e2_high_cpu_price_df_sorted["TPS PER DOLLAR"], 
    marker="o", 
    linestyle="-", 
    label="e2-highcpu",
    linewidth=4,
    markersize=15,
)
plt.plot(
    c3d_high_cpu_price_df_sorted["CPU CORES ALLOCATED"], 
    c3d_high_cpu_price_df_sorted["TPS PER DOLLAR"], 
    marker="o", 
    linestyle="-", 
    label="c3d-highcpu",
    linewidth=4,
    markersize=15,
)
plt.plot(
    c2d_high_cpu_price_df_sorted["CPU CORES ALLOCATED"], 
    c2d_high_cpu_price_df_sorted["TPS PER DOLLAR"], 
    marker="o", 
    linestyle="-", 
    label="c2d-highcpu",
    linewidth=4,
    markersize=15,
)
plt.title("Price to Performance", fontsize=16)
plt.xlabel("CPU Cores Allocated", fontsize=14)
plt.ylabel("TPS/$", fontsize=14)
plt.xticks(e2_price_df_sorted["CPU CORES ALLOCATED"], fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis="both", linestyle="-", alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
